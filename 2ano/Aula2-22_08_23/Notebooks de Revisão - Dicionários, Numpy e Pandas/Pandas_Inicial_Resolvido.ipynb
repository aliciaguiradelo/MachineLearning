# %% [markdown]
# # **Introdução ao Pandas**
#
# Pandas é uma ferramenta de manipulação de dados de alto nível, construída com base no pacote Numpy.
#
# Series: arrays unidimensionais rotulados capazes de armazenar qualquer tipo de dado.
#
# Data Frames: estruturas de dados tabulares bidimensionais com rótulos nas linhas e colunas. Assim como as series, os dataframes são capazes de armazenar qualquer tipo de dado.

# %%
# Importando o pacote Pandas
import pandas as pd

# %%
# Importando uma base de dados
dados = pd.read_csv('goalkeeping.csv')
# dados = pd.read_csv('goalkeeping.csv', index_col='player_name')
dados

# %% [markdown]
# Informações Gerais da base de dados

# %%
# Tamanho da base
dados.shape
# Out:
# (53, 10)

# %%
# Primeiras linhas
dados.head()
# Out:
#    serial   player_name         club    position  saved  conceded  \
# 0       1      Courtois  Real Madrid  Goalkeeper     61        14
# 1       2         Rulli   Villarreal  Goalkeeper     41        16
# 2       3   Vlachodimos      Benfica  Goalkeeper     38        17
# 3       4  Athanasiadis      Sheriff  Goalkeeper     29         8
# 4       5      Mignolet  Club Brugge  Goalkeeper     28        20
#
#    saved_penalties  cleansheets  punches made  match_played
# 0                1            5             4            13
# 1                0            3            12            12
# 2                1            5             5            10
# 3                0            1             2             5
# 4                0            0             1             6

# %%
# Últimas linhas
dados.tail()
# Out:
#     serial player_name              club    position  saved  conceded  \
# 48      46    Martínez           Leipzig  Goalkeeper      3         0
# 49      50       Onana              Ajax  Goalkeeper      2         2
# 50      50       Perin          Juventus  Goalkeeper      2         0
# 51      52  Shevchenko  Shakhtar Donetsk  Goalkeeper      1         1
# 52      52      Carson         Man. City  Goalkeeper      1         0
#
#     saved_penalties  cleansheets  punches made  match_played
# 48                0            1             0             1
# 49                0            0             0             2
# 50                0            1             0             1
# 51                0            0             0             1
# 52                0            1             0             1

# %%
# Acessando colunas (como Serie):
dados['club']
# Out:
# 0          Real Madrid
# 1           Villarreal
# 2              Benfica
# 3              Sheriff
# 4          Club Brugge
# 5             Atlético
# 6             Atalanta
# 7             Beşiktaş
# 8          Man. United
# 9                Malmö
# 10               Porto
# 11    Shakhtar Donetsk
# 12           Wolfsburg
# 13               Paris
# 14         Sporting CP
# 15            Salzburg
# 16           Barcelona
# 17           Liverpool
# 18           Man. City
# 19            Dortmund
# 20            Juventus
# 21               Milan
# 22              Bayern
# 23             Sevilla
# 24         Dynamo Kyiv
# 25                Ajax
# 26               Malmö
# 27                LOSC
# 28               Inter
# 29               Zenit
# 30          Young Boys
# 31             Leipzig
# 32               Paris
# 33             Chelsea
# 34          Young Boys
# 35               Milan
# 36             Sheriff
# 37               Zenit
# 38    Shakhtar Donetsk
# 39           Wolfsburg
# ...

# %%
# Acessando colunas (como Data Frame):
dados[['club', 'player_name', 'conceded']]
# Out:
#                 club       player_name  conceded
# 0        Real Madrid          Courtois        14
# 1         Villarreal             Rulli        16
# 2            Benfica       Vlachodimos        17
# 3            Sheriff      Athanasiadis         8
# 4        Club Brugge          Mignolet        20
# 5           Atlético             Oblak        10
# 6           Atalanta             Musso        13
# 7           Beşiktaş  Ersin Destanoğlu        17
# 8        Man. United            De Gea         9
# 9              Malmö            Dahlin         8
# 10             Porto       Diogo Costa        11
# 11  Shakhtar Donetsk            Trubin         9
# 12         Wolfsburg          Casteels         8
# 13             Paris        Donnarumma         6
# 14       Sporting CP              Adán        13
# 15          Salzburg              Köhn        14
# 16         Barcelona        Ter Stegen         9
# 17         Liverpool    Alisson Becker        14
# ...

# %%
# Selecionando linhas (slicing):
dados[19:30]
# Out:
#     serial player_name         club    position  saved  conceded  \
# 19      19       Kobel     Dortmund  Goalkeeper     14        11
# 20      19    Szczęsny     Juventus  Goalkeeper     14        10
# 21      19     Maignan        Milan  Goalkeeper     14         7
# 22      19       Neuer       Bayern  Goalkeeper     14         6
# 23      19      Bounou      Sevilla  Goalkeeper     14         5
# 24      25    Bushchan  Dynamo Kyiv  Goalkeeper     13        11
# 25      25     Pasveer         Ajax  Goalkeeper     13         6
# 26      25     Diawara        Malmö  Goalkeeper     13         6
# 27      25       Grbić         LOSC  Goalkeeper     13         4
# 28      29  Handanovič        Inter  Goalkeeper     12         7
# 29      29    Kritsyuk        Zenit  Goalkeeper     12         6
#
#     saved_penalties  cleansheets  punches made  match_played
# 19                1            2             1             6
# 20                0            3             3             7
# ...

# %%
# Alterando a ordem das colunas:
# Exemplo: Trocando 'club' e 'position'.
dados1 = dados[['serial',	'player_name',	'position',	'club',	'saved',	'conceded',	'saved_penalties',	'cleansheets',	'punches made',	'match_played']]

# %%
dados1.head()
# Out:
#    serial   player_name    position         club  saved  conceded  \
# 0       1      Courtois  Goalkeeper  Real Madrid     61        14
# 1       2         Rulli  Goalkeeper   Villarreal     41        16
# 2       3   Vlachodimos  Goalkeeper      Benfica     38        17
# 3       4  Athanasiadis  Goalkeeper      Sheriff     29         8
# 4       5      Mignolet  Goalkeeper  Club Brugge     28        20
#
#    saved_penalties  cleansheets  punches made  match_played
# 0                1            5             4            13
# 1                0            3            12            12
# 2                1            5             5            10
# 3                0            1             2             5
# 4                0            0             1             6

# %%
# Removendo colunas ('chave', axis=1):
dados1 = dados1.drop(columns=['punches made'])
dados1

# %%
dados1 = dados1.drop('cleansheets', axis=1)
dados1
# Out:
#     serial       player_name    position              club  saved  conceded  \
# 0        1          Courtois  Goalkeeper       Real Madrid     61        14
# 1        2             Rulli  Goalkeeper        Villarreal     41        16
# 2        3       Vlachodimos  Goalkeeper           Benfica     38        17
# 3        4      Athanasiadis  Goalkeeper           Sheriff     29         8
# 4        5          Mignolet  Goalkeeper       Club Brugge     28        20
# 5        6             Oblak  Goalkeeper          Atlético     26        10
# 6        7             Musso  Goalkeeper          Atalanta     21        13
# 7        8  Ersin Destanoğlu  Goalkeeper          Beşiktaş     20        17
# 8        9            De Gea  Goalkeeper       Man. United     19         9
# 9        9            Dahlin  Goalkeeper             Malmö     19         8
# 10      11       Diogo Costa  Goalkeeper             Porto     18        11
# ...

# %%
# Selecionando linhas e colunas com o .loc:

# %%
# Selecionando todas as linhas e algumas colunas:

# %%
# Selecionando linhas com o .iloc
